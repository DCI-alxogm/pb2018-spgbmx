# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.constants as sc
#Para activar los graficos en el notebook
# %matplotlib inline

# %%
f= np.loadtxt('IRCF.txt').T
np.shape(f)
# Out:
# (5, 43)

# %%
x=f[0] #frecuencia
y=f[1] #espectro
z=f[3] #incertidumbre

# %%
plt.plot(x,y)
plt.errorbar(x,y,yerr=z)
plt.grid()

# %%
plt.plot(z)

# %%
#utilizando la libreria de constantes
h=sc.Planck
k=sc.Boltzmann
c=sc.c

# %%
print(h,k,c)
# Out:
# 6.62607004e-34 1.38064852e-23 299792458.0

# %%
v=1 #valor provisional
T=1 #valor provisional
a=(h*v**3)/c**2
b=(1/(np.exp(h*v/k*T))-1)

# %%
I=lambda x: a*b
